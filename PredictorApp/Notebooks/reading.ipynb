# %%
import datetime
import pandas as pd

import os

# %%
#!pip install matplotlib
import matplotlib.pyplot as plt

start_date = datetime.datetime(2018, 2, 1, 0, 0, 0, 0, datetime.timezone.utc)
end_date = datetime.datetime(2018, 3, 1, 23, 0, 0, 0, datetime.timezone.utc)

filelist = ["../Data/2018-Weighted/unprocessed/10 2018.csv",

            ]

# %%
for file_path in filelist:
    try:
        volume_data = pd.read_csv(file_path, sep=";")
        print("sep")
    except:
        volume_data = pd.read_csv(file_path, lineterminator="\n")
        print("lineterminator")

    volume_data = volume_data.sort_values(by='date')

    try:
        volume_data['date'] = pd.to_datetime(volume_data['date'], format='%d/%m/%Y %H:%M:%S')
    except:
        try:
            volume_data['date'] = pd.to_datetime(volume_data['date'], format='%d/%m/%Y %H:%M')
        except:
            volume_data['date'] = pd.to_datetime(volume_data['date'], format='%Y-%m-%d %H:%M:%S')


    volume_data['date'] = volume_data["date"].dt.tz_localize(None)
    volume_data = volume_data.set_index("date")

    grouped_data = volume_data.groupby(pd.Grouper(freq="60Min")).size().reset_index(name='tweet_vol')
    plt.close()
    grouped_data.plot(x='date')
    plt.show()

    print(file_path)
    print(volume_data.shape)
# Out:
# lineterminator
# ../Data/2018-Weighted/unprocessed/10 2018.csv
# (527950, 21)

# %%
import datetime
import pytz

utc=pytz.UTC
volume_data['date'] = pd.to_datetime(volume_data['date'], format='%Y-%m-%d %H:%M:%S',utc=True)

# %%
volume_data = volume_data.set_index("date")

grouped_data = volume_data.groupby(pd.Grouper(freq="60Min")).size().reset_index(name='tweet_vol')
plt.close()
grouped_data.plot(x='date')
plt.show()

print(file_path)
print(volume_data.shape)
# Out:
# raw_data/mix/Per Period/2018(03-08--03-11).csv
# (7167483, 28)

# %%
import pandas as pd
file_path = "raw_data/mix/Per Period/2018(03-08--03-11).csv"

try:
    data = pd.read_csv(file_path, sep=";")
except:
    data = pd.read_csv(file_path, lineterminator="\n")
data.shape
# Out:
# C:\ProgramData\Anaconda3\envs\PredictorApp\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (13,14,15,22,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# (7167483, 29)

# %%
start_date = datetime.datetime(2018, 3, 8, 0, 0, 0, 0, datetime.timezone.utc)
end_date = datetime.datetime(2018, 6, 1, 0, 0, 0, 0, datetime.timezone.utc)
data = data.drop('column_name', 1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4968/2955346459.py in <module>
#       1 start_date = datetime.datetime(2018, 3, 8, 0, 0, 0, 0, datetime.timezone.utc)
#       2 end_date = datetime.datetime(2018, 6, 1, 0, 0, 0, 0, datetime.timezone.utc)
# ----> 3 data['Date'] = pd.to_datetime(data['date'])
#       4 data1 = data.loc[(data['Date'] >= start_date.replace(tzinfo=None))
#       5             & (data['Date'] < end_date.replace(tzinfo=None))]
#
# C:\ProgramData\Anaconda3\envs\PredictorApp\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     885             result = arg.map(cache_array)
#     886         else:
# --> 887             values = convert_listlike(arg._values, format)
#     888             result = arg._constructor(values, index=arg.index, name=arg.name)
#     889     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# C:\ProgramData\Anaconda3\envs\PredictorApp\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     399     assert format is None or infer_datetime_format
#     400     utc = tz == "utc"
# --> 401     result, tz_parsed = objects_to_datetime64ns(
#     402         arg,
#     403         dayfirst=dayfirst,
#
# C:\ProgramData\Anaconda3\envs\PredictorApp\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2173     order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2174     try:
# -> 2175         result, tz_parsed = tslib.array_to_datetime(
#    2176             data.ravel("K"),
#    2177             errors=errors,
#
# C:\ProgramData\Anaconda3\envs\PredictorApp\lib\site-packages\pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# C:\ProgramData\Anaconda3\envs\PredictorApp\lib\site-packages\pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# C:\ProgramData\Anaconda3\envs\PredictorApp\lib\site-packages\pandas\_libs\tslib.pyx in pandas._libs.tslib._array_to_datetime_object()
#
# C:\ProgramData\Anaconda3\envs\PredictorApp\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# C:\ProgramData\Anaconda3\envs\PredictorApp\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing._parse_dateabbr_string()
#
# C:\ProgramData\Anaconda3\envs\PredictorApp\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# C:\ProgramData\Anaconda3\envs\PredictorApp\lib\_strptime.py in _strptime(data_string, format)
#     320     with _cache_lock:
#     321         locale_time = _TimeRE_cache.locale_time
# --> 322         if (_getlang() != locale_time.lang or
#     323             time.tzname != locale_time.tzname or
#     324             time.daylight != locale_time.daylight):
#
# C:\ProgramData\Anaconda3\envs\PredictorApp\lib\_strptime.py in _getlang()
#      26 def _getlang():
#      27     # Figure out what the current language is set to.
# ---> 28     return locale.getlocale(locale.LC_TIME)
#      29
#      30 class LocaleTime(object):
#
# C:\ProgramData\Anaconda3\envs\PredictorApp\lib\locale.py in getlocale(category)
#     589     """
#     590     localename = _setlocale(category)
# --> 591     if category == LC_ALL and ';' in localename:
#     592         raise TypeError('category LC_ALL is not supported')
#     593     return _parse_localename(localename)
#
# KeyboardInterrupt:

# %%
data['Date'] = pd.to_datetime(data['date'])
data1 = data.loc[(data['Date'] >= start_date.replace(tzinfo=None))
            & (data['Date'] < end_date.replace(tzinfo=None))]
